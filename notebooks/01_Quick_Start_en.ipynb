# %% [markdown]
# # 🚀 Quick Start with Climatology Engine
#
# This notebook provides a quick introduction to the Climatology Engine.
#
# **What you will learn:**
# - Loading sample data
# - Fitting a Normal distribution
# - Viewing results
#
# ---

# %%
import sys
import os
project_root = os.path.abspath('..')
if project_root not in sys.path:
    sys.path.insert(0, project_root)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

print('✅ Libraries loaded.')
print(f'NumPy: {np.__version__}')
print(f'Pandas: {pd.__version__}')

# %%
# Load sample data
sample_dir = os.path.join(project_root, 'sample_data')
station_files = sorted([f for f in os.listdir(sample_dir) if f.endswith('.csv')])
print(f'✅ Number of sample stations: {len(station_files)}')
print(f'   Files: {station_files[:5]}...')

# Load the first station
station_data = pd.read_csv(os.path.join(sample_dir, station_files[0]))
print(f'📊 Data shape: {station_data.shape}')
print(f'   Columns: {station_data.columns.tolist()}')
station_data.head()

# %%
# Display one year of data
data = station_data.values
n_days = 365

fig, axes = plt.subplots(3, 1, figsize=(14, 10), sharex=True)

axes[0].plot(data[:n_days, 0], color='blue', alpha=0.7, linewidth=1.5)
axes[0].set_ylabel('tmin (°C)')
axes[0].set_title('Minimum Temperature - Station 1 (First Year)')
axes[0].grid(True, alpha=0.3)

axes[1].plot(data[:n_days, 1], color='green', alpha=0.7, linewidth=1.5)
axes[1].set_ylabel('tmean (°C)')
axes[1].set_title('Mean Temperature')
axes[1].grid(True, alpha=0.3)

axes[2].plot(data[:n_days, 2], color='red', alpha=0.7, linewidth=1.5)
axes[2].set_xlabel('Day of Year')
axes[2].set_ylabel('tmax (°C)')
axes[2].set_title('Maximum Temperature')
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
from plugins.distributions.normal import NormalDistribution

# Select tmean data for one year
data_year = data[:365, 1]
print(f'📊 Number of samples: {len(data_year)}')
print(f'   Mean: {np.mean(data_year):.2f}°C')
print(f'   Standard deviation: {np.std(data_year):.2f}°C')

# Fit Normal distribution
dist = NormalDistribution()
result = dist.fit(data_year)

print('\n📈 Fit results:')
for key, value in result.items():
    if isinstance(value, float):
        print(f'   {key}: {value:.4f}')
    else:
        print(f'   {key}: {value}')

# %%
from scipy.stats import norm

mu = result['p1']
sigma = result['p2']

fig, ax = plt.subplots(figsize=(10, 6))

ax.hist(data_year, bins=30, density=True, alpha=0.6, color='blue', edgecolor='black', label='Data')

x = np.linspace(min(data_year), max(data_year), 200)
pdf = norm.pdf(x, mu, sigma)
ax.plot(x, pdf, 'r-', linewidth=2.5, label=f'Normal(μ={mu:.2f}, σ={sigma:.2f})')

ax.set_xlabel('Temperature (°C)')
ax.set_ylabel('Probability Density')
ax.set_title('Normal Distribution Fit on Temperature Data')
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📋 Summary
#
# In this notebook you learned:
#
# ✅ Loading sample data
# ✅ Fitting a Normal distribution
# ✅ Plotting histogram and distribution curve
#
# ---
#
# **Next Steps:**
# - Notebook 02: Data Preparation
# - Notebook 03: Fitting All Distributions
